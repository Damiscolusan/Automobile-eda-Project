# %% [markdown]
# <a href="https://colab.research.google.com/github/Damiscolusan/Automobile-eda-Project/blob/main/Students_Score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
% matplotlib.inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
df= pd.read_csv('students_score_data.csv')
df
# Out:
#            Name  Gender  Math_score  English_score  Science_score  \
# 0      Student1    Male          91             68             85
# 1      Student2  Female          73             86             81
# 2      Student3  Female          88             75             97
# 3      Student4    Male          97             60             51
# 4      Student5  Female          84             57             51
# ..          ...     ...         ...            ...            ...
# 195  Student196  Female          75             52             68
# 196  Student197  Female          64             57             97
# 197  Student198  Female          60             81             67
# 198  Student199    Male          61             75             80
# 199  Student200    Male          65             69             54
#
#      Attendance_rate  Overall_performance
# 0               0.74                 80.6
# 1               0.80                 80.0
# 2               0.95                 87.5
# ...

# %%
df.head()
# Out:
#        Name  Gender  Math_score  English_score  Science_score  \
# 0  Student1    Male          91             68             85
# 1  Student2  Female          73             86             81
# 2  Student3  Female          88             75             97
# 3  Student4    Male          97             60             51
# 4  Student5  Female          84             57             51
#
#    Attendance_rate  Overall_performance
# 0             0.74                 80.6
# 1             0.80                 80.0
# 2             0.95                 87.5
# 3             0.84                 70.8
# 4             0.81                 65.7

# %%
df.shape
# Out:
# (200, 7)

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'Math_score', 'English_score', 'Science_score',
#        'Attendance_rate', 'Overall_performance'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name                    object
# Gender                  object
# Math_score               int64
# English_score            int64
# Science_score            int64
# Attendance_rate        float64
# Overall_performance    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 200 non-null    object
#  1   Gender               200 non-null    object
#  2   Math_score           200 non-null    int64
#  3   English_score        200 non-null    int64
#  4   Science_score        200 non-null    int64
#  5   Attendance_rate      200 non-null    float64
#  6   Overall_performance  200 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 11.1+ KB

# %% [markdown]
# ## Basic descriptive statistics

# %%
df.describe()
# Out:
#        Math_score  English_score  Science_score  Attendance_rate  \
# count  200.000000     200.000000     200.000000       200.000000
# mean    75.010000      74.895000      74.895000         0.853300
# std     13.984554      14.535141      15.567134         0.084907
# min     50.000000      50.000000      50.000000         0.700000
# 25%     63.750000      62.000000      61.000000         0.787500
# 50%     75.000000      75.000000      74.000000         0.860000
# 75%     87.000000      87.250000      88.000000         0.930000
# max    100.000000     100.000000     100.000000         1.000000
#
#        Overall_performance
# count           200.000000
# mean             75.973000
# std               7.704855
# min              58.400000
# 25%              70.175000
# 50%              75.750000
# 75%              81.725000
# max              94.300000

# %%
df.isnull().sum()
# Out:
# Name                   0
# Gender                 0
# Math_score             0
# English_score          0
# Science_score          0
# Attendance_rate        0
# Overall_performance    0
# dtype: int64

# %%
df.Gender.nunique()
# Out:
# 2

# %%
df['Gender'].value_counts(ascending=False)
# Out:
# Gender
# Female    104
# Male       96
# Name: count, dtype: int64

# %%
df.isna().mean()
# Out:
# Name                   0.0
# Gender                 0.0
# Math_score             0.0
# English_score          0.0
# Science_score          0.0
# Attendance_rate        0.0
# Overall_performance    0.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'Math_score', 'English_score', 'Science_score',
#        'Attendance_rate', 'Overall_performance'],
#       dtype='object')

# %%
# print(df.Math_score.mean())
# print()
# print(df.Math_score.values)
# print()
# print(df.Math_score.value_counts())
# print(df.Math_score.sort_values())

# %%
df['Math_score'].hist( color='skyblue', edgecolor= 'black')
plt.title('Distribution of Math score')
plt.ylabel('Frequency_Count')
plt.xlabel('Math score', color ='red', fontsize= 12)
plt.show()
