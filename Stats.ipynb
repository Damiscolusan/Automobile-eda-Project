# %% [markdown]
# <a href="https://colab.research.google.com/github/Damiscolusan/Automobile-eda-Project/blob/main/Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Descriptive Statistics
# Exercise: Given a dataset of student scores in two subjects, calculate the mean, median, mode, and range.

# %%
import pandas as pd

# Sample data
data = {'Math Score': [14, 19, 13, 9, 13],
        'Reading Score': [25, 37, 26, 20, 19]}
df = pd.DataFrame(data)
df
# Out:
#    Math Score  Reading Score
# 0          14             25
# 1          19             37
# 2          13             26
# 3           9             20
# 4          13             19

# %%
# Descriptive statistics
mean =   df.mean()
median =  df.median()
mode = df.mode().iloc[0]  # Mode can return multiple values, we use the first one
range = df.max() - df.min()

# Display results
print("Mean:\n", mean)
print("\nMedian:\n", median)
print("\nMode:\n", mode)
print("\nRange:\n", range)
# Out:
# Mean:
#  Math Score       13.6
# Reading Score    25.4
# dtype: float64
#
# Median:
#  Math Score       13.0
# Reading Score    25.0
# dtype: float64
#
# Mode:
#  Math Score       13.0
# Reading Score    19.0
# Name: 0, dtype: float64
#
# Range:
#  Math Score       10
# Reading Score    18
# dtype: int64

# %% [markdown]
#  Variance and Standard Deviation
# Exercise: Given a set of scores, calculate the variance and standard deviation.

# %%
import numpy as np

data = [2, 9, 7, 5, 3, 1]

mean = np.mean(data)
variance = np.var(data)
std_deviation =  np.std(data)

print("Mean:", mean)
print("Variance:", variance)
print("Standard Deviation:", std_deviation)
# Out:
# Mean: 4.5
# Variance: 7.916666666666667
# Standard Deviation: 2.8136571693556887

# %% [markdown]
# Percentiles and Quartiles
# Exercise: Using a dataset of exam scores, calculate the 10th, 50th, and 90th percentiles as well as the 1st and 3rd quartiles.

# %%
# Sample data
exam_scores = [42, 37, 55, 65, 23, 79, 85, 40, 50, 30]

# Percentiles
percentiles =  np.quantile(exam_scores, [0.1, 0.5, 0.9])
quartiles =  np.quantile(0.1, 0.3)

print("10th, 50th, 90th Percentiles:", percentiles)
print("1st and 3rd Quartiles:", quartiles)
# Out:
# 10th, 50th, 90th Percentiles: [29.3 46.  79.6]
# 1st and 3rd Quartiles: 0.1

# %% [markdown]
# Normal Distribution
# Exercise: Suppose that exam scores are normally distributed with a mean of 50 and standard deviation of 10. Calculate the percentage of students scoring:
#
# Below 50
# Above 60
# Between 40 and 60

# %%
from scipy.stats import norm

mean = 50
std_dev = 10

# P(X < 50)
# below_50 =  #add your code here
# below_50 =norm.cdf(50, loc=mean, scale=std_dev)
below_50 = norm.cdf(50, loc = mean, scale = std_dev)

# P(X > 60)
# above_60 = #add your code here
above_60 = 1-norm.cdf (60, loc = mean, scale = std_dev)

# P(40 < X < 60)
# between_40_60 = #add your code here
between_40_60 = norm.cdf (60, loc = mean, scale = std_dev)- norm.cdf(40, loc = mean, scale = std_dev)
print(f"Below 50: {below_50*100:.2f}%")
print(f"Above 60: {above_60*100:.2f}%")
print(f"Between 40 and 60: {between_40_60*100:.2f}%")
# Out:
# Below 50: 50.00%
# Above 60: 15.87%
# Between 40 and 60: 68.27%

# %% [markdown]
# Z-Scores
# Exercise: Calculate Z-scores for the following students' scores:
#
# Alice: 45
# Bob: 48
# Chloe: 38
# Dave: 35 Mean score: 42, Standard Deviation: 3

# %%
from scipy.stats import zscore
import numpy as np

scores = np.array([45, 48, 38, 35])
mean = 42
std_dev = 3

# Z-scores
# z_scores = #add your code here
z_scores = zscore(scores)
print("Z-scores:", z_scores)
# Out:
# Z-scores: [ 0.6704784   1.24517417 -0.6704784  -1.24517417]

# %% [markdown]
# Correlation Coefficients
# Exercise: Calculate the Pearson correlation coefficient between two variables: Attendance and Exam Results.

# %%
# Sample data
data = {'Attendance': [75, 78, 88, 80, 78],
        'Result': [37, 41, 48, 32, 36]}

df = pd.DataFrame(data)

# Pearson correlation
# correlation = #add your code here
correlation = df.corr()
print("Correlation matrix:\n", correlation)
# Out:
# Correlation matrix:
#              Attendance    Result
# Attendance    1.000000  0.702981
# Result        0.702981  1.000000
